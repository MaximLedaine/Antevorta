# %%
import requests as requests
import json
import yfinance as yf
import pandas as pd

# %%
stock = yf.Ticker("AAPL")

# get stock info
stock.info

# get historical market data
hist = stock.history(period="max")

# show actions (dividends, splits)
stock.actions

# show dividends
stock.dividends

# show splits
stock.splits

# show financials
stock.financials

# show balance heet
stock.balance_sheet

# show cashflow
stock.cashflow

# show options expirations
stock.options
# Out:
# ('2019-09-06',
#  '2019-09-13',
#  '2019-09-20',
#  '2019-09-27',
#  '2019-10-04',
#  '2019-10-11',
#  '2019-10-18',
#  '2019-11-15',
#  '2019-12-20',
#  '2020-01-17',
#  '2020-03-20',
#  '2020-04-17',
#  '2020-06-19',
#  '2020-09-18',
#  '2021-01-15',
#  '2021-06-18')

# %%
stock.cashflow
# Out:
#                                                     9/29/2018  9/30/2017  \
#
# Net Income                                           59531000   48351000
# Operating Activities, Cash Flows Provided By or...          -          -
# Depreciation                                         10903000   10157000
# Adjustments To Net Income                           -27694000   10640000
# Changes In Accounts Receivables                      -5322000   -2093000
# Changes In Liabilities                                9131000    8340000
# Changes In Inventories                                 828000   -2723000
# Changes In Other Operating Activities                30057000   -8447000
# Total Cash Flow From Operating Activities            77434000   64225000
# Investing Activities, Cash Flows Provided By or...          -          -
# Capital Expenditure                                 -13313000  -12451000
# Investments                                          30845000  -33542000
# Other Cash flows from Investing Activities            -745000    -124000
# Total Cash Flows From Investing Activities           16066000  -46446000
# Financing Activities, Cash Flows Provided By or...          -          -
# Dividends Paid                                      -13712000  -12769000
# Sale Purchase of Stock                                    NaN        NaN
# Net Borrowings                                         432000   29014000
# Other Cash Flows from Financing Activities                NaN        NaN
# Total Cash Flows From Financing Activities          -87876000  -17974000
# Effect Of Exchange Rate Changes                           NaN        NaN
# Change In Cash and Cash Equivalents                   5624000    -195000
#
#                                                     9/24/2016  9/26/2015
#
# Net Income                                           45687000   53394000
# Operating Activities, Cash Flows Provided By or...          -          -
# Depreciation                                         10505000   11257000
# Adjustments To Net Income                             9634000    5353000
# Changes In Accounts Receivables                        527000     417000
# Changes In Liabilities                                 563000    6043000
# Changes In Inventories                                 217000    -238000
# Changes In Other Operating Activities                 -902000    5040000
# Total Cash Flow From Operating Activities            66231000   81266000
# Investing Activities, Cash Flows Provided By or...          -          -
# Capital Expenditure                                 -12734000  -11247000
# Investments                                         -32022000  -44417000
# Other Cash flows from Investing Activities            -924000     -26000
# Total Cash Flows From Investing Activities          -45977000  -56274000
# Financing Activities, Cash Flows Provided By or...          -          -
# Dividends Paid                                      -12150000  -11561000
# Sale Purchase of Stock                                    NaN        NaN
# Net Borrowings                                       22057000   29305000
# Other Cash Flows from Financing Activities                NaN     749000
# Total Cash Flows From Financing Activities          -20890000  -17716000
# Effect Of Exchange Rate Changes                           NaN        NaN
# Change In Cash and Cash Equivalents                   -636000    7276000

# %%
proxy = "http://200.255.122.170:8080"

stock = yf.Ticker("MSFT")

# stock.history(..., proxy=proxy)
# stock.get_actions(proxy=proxy)
# stock.get_dividends(proxy=proxy)
# stock.get_splits(proxy=proxy)
# stock.get_balance_sheet(proxy=proxy)
# stock.get_cashflow(proxy=proxy)
# stock.option_chain(..., proxy=proxy)

# %%
stock = yf.Ticker("AAPL")
stock.get_balance_sheet(proxy=proxy)
# Out:
#                                       9/29/2018  9/30/2017  9/24/2016  \
#
# Current Assets                                -          -          -
# Cash And Cash Equivalents              25913000   20289000   20484000
# Short Term Investments                 40388000   53892000   46671000
# Net Receivables                        48995000   35673000   29299000
# Inventory                               3956000    4855000    2132000
# Other Current Assets                   12087000   13936000    8283000
# Total Current Assets                  131339000  128645000  106869000
# Long Term Investments                 170799000  194714000  170430000
# Property, plant and equipment          41304000   33783000   27010000
# Goodwill                                    NaN        NaN    5414000
# Intangible Assets                           NaN        NaN    3206000
# Accumulated Amortization                    NaN        NaN        NaN
# Other Assets                           22283000   18177000    8757000
# Deferred Long Term Asset Charges            NaN        NaN        NaN
# Total Assets                          365725000  375319000  321686000
# Current Liabilities                           -          -          -
# Accounts Payable                       55888000   44242000   37294000
# Short/Current Long Term Debt            8784000    6496000    3500000
# Other Current Liabilities              40230000   38099000    8243000
# Total Current Liabilities             116866000  100814000   79006000
# Long Term Debt                         93735000   97207000   75427000
# Other Liabilities                      47977000   43251000   39004000
# Deferred Long Term Liability Charges        NaN        NaN        NaN
# Minority Interest                           NaN        NaN        NaN
# Negative Goodwill                           NaN        NaN        NaN
# Total Liabilities                     258578000  241272000  193437000
# Stockholders' Equity                          -          -          -
# Misc. Stocks Options Warrants               NaN        NaN        NaN
# Redeemable Preferred Stock                  NaN        NaN        NaN
# Preferred Stock                             NaN        NaN        NaN
# Common Stock                           40201000   35867000   31251000
# Retained Earnings                      70400000   98330000   96364000
# Treasury Stock                         -3454000    -150000     634000
# Capital Surplus                             NaN        NaN        NaN
# Other Stockholder Equity               -3454000    -150000     634000
# Total stockholders' equity            107147000  134047000  128249000
# Net Tangible Assets                   107147000  134047000  119629000
#
#                                       9/26/2015
#
# Current Assets                                -
# Cash And Cash Equivalents              21120000
# Short Term Investments                 20481000
# Net Receivables                        30343000
# Inventory                               2349000
# Other Current Assets                   14691000
# Total Current Assets                   89378000
# Long Term Investments                 164065000
# Property, plant and equipment          22471000
# Goodwill                                5116000
# Intangible Assets                       3893000
# Accumulated Amortization                    NaN
# Other Assets                            5422000
# Deferred Long Term Asset Charges            NaN
# Total Assets                          290345000
# Current Liabilities                           -
# Accounts Payable                       35490000
# Short/Current Long Term Debt            2513000
# Other Current Liabilities              10939000
# Total Current Liabilities              80610000
# Long Term Debt                         53329000
# Other Liabilities                      37051000
# Deferred Long Term Liability Charges        NaN
# Minority Interest                           NaN
# Negative Goodwill                           NaN
# Total Liabilities                     170990000
# Stockholders' Equity                          -
# Misc. Stocks Options Warrants               NaN
# Redeemable Preferred Stock                  NaN
# Preferred Stock                             NaN
# Common Stock                           27416000
# Retained Earnings                      92284000
# Treasury Stock                          -345000
# Capital Surplus                             NaN
# Other Stockholder Equity                -345000
# Total stockholders' equity            119355000
# Net Tangible Assets                   110346000

# %%
stock = yf.Ticker("AAPL")
stock.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'currency': 'USD',
#  'sharesOutstanding': 4601079808,
#  'fiftyDayAverageChange': -0.39343262,
#  'fiftyDayAverageChangePercent': -0.0019121558,
#  'twoHundredDayAverage': 194.92868,
#  'twoHundredDayAverageChange': 10.43132,
#  'twoHundredDayAverageChangePercent': 0.053513523,
#  'regularMarketChangePercent': -1.6192416,
#  'regularMarketDayRange': '204.22 - 206.98',
#  'bid': 205.23,
#  'esgPopulated': False,
#  'tradeable': True,
#  'triggerable': True,
#  'regularMarketPrice': 205.36,
#  'regularMarketTime': 1567537088,
#  'regularMarketChange': -3.380005,
#  'regularMarketOpen': 206.43,
#  'regularMarketDayHigh': 206.98,
#  'regularMarketDayLow': 204.22,
#  'regularMarketVolume': 15130758,
#  'epsTrailingTwelveMonths': 11.777,
#  'epsForward': 12.79,
#  'bookValue': 21.286,
#  'fiftyDayAverage': 205.75343,
#  'marketState': 'REGULAR',
#  'priceHint': 2,
#  'regularMarketPreviousClose': 208.74,
#  'ask': 205.24,
#  'bidSize': 10,
#  'askSize': 10,
#  'messageBoardId': 'finmb_24937',
#  'fullExchangeName': 'NasdaqGS',
#  'longName': 'Apple Inc.',
#  'financialCurrency': 'USD',
#  'averageDailyVolume3Month': 26097660,
#  'averageDailyVolume10Day': 21997920,
#  'fiftyTwoWeekLowChange': 63.36,
#  'fiftyTwoWeekLowChangePercent': 0.44619718,
#  'fiftyTwoWeekRange': '142.0 - 233.47',
#  'exchangeDataDelayedBy': 0,
#  'fiftyTwoWeekHighChange': -28.11,
#  'fiftyTwoWeekHighChangePercent': -0.12040091,
#  'fiftyTwoWeekLow': 142.0,
#  'fiftyTwoWeekHigh': 233.47,
#  'dividendDate': 1565827200,
#  'earningsTimestamp': 1564531200,
#  'earningsTimestampStart': 1572447540,
#  'earningsTimestampEnd': 1572886800,
#  'trailingAnnualDividendRate': 2.96,
#  'trailingPE': 17.437378,
#  'trailingAnnualDividendYield': 0.014180319,
#  'market': 'us_market',
#  'shortName': 'Apple Inc.',
#  'exchange': 'NMS',
#  'marketCap': 913786273792,
#  'forwardPE': 16.056293,
#  'priceToBook': 9.647656,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'symbol': 'AAPL'}
